# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
meds = pd.read_csv('Medicine_Details.csv')

# %%
meds.head()
# Out:
#               Medicine Name  \
# 0   Avastin 400mg Injection
# 1  Augmentin 625 Duo Tablet
# 2       Azithral 500 Tablet
# 3          Ascoril LS Syrup
# 4         Aciloc 150 Tablet
#
#                                          Composition  \
# 0                                Bevacizumab (400mg)
# 1    Amoxycillin  (500mg) +  Clavulanic Acid (125mg)
# 2                               Azithromycin (500mg)
# 3  Ambroxol (30mg/5ml) + Levosalbutamol (1mg/5ml)...
# 4                                 Ranitidine (150mg)
#
#                                                 Uses  \
# 0   Cancer of colon and rectum Non-small cell lun...
# 1                  Treatment of Bacterial infections
# 2                  Treatment of Bacterial infections
# 3                      Treatment of Cough with mucus
# 4  Treatment of Gastroesophageal reflux disease (...
#
#                                         Side_effects  \
# 0  Rectal bleeding Taste change Headache Noseblee...
# ...

# %%
meds = meds[['Medicine Name', 'Composition', 'Uses', 'Side_effects', 'Image URL', 'Manufacturer', 'Excellent Review %', 'Average Review %', 'Poor Review %']]
meds.head(5)
# Out:
#               Medicine Name  \
# 0   Avastin 400mg Injection
# 1  Augmentin 625 Duo Tablet
# 2       Azithral 500 Tablet
# 3          Ascoril LS Syrup
# 4         Aciloc 150 Tablet
#
#                                          Composition  \
# 0                                Bevacizumab (400mg)
# 1    Amoxycillin  (500mg) +  Clavulanic Acid (125mg)
# 2                               Azithromycin (500mg)
# 3  Ambroxol (30mg/5ml) + Levosalbutamol (1mg/5ml)...
# 4                                 Ranitidine (150mg)
#
#                                                 Uses  \
# 0   Cancer of colon and rectum Non-small cell lun...
# 1                  Treatment of Bacterial infections
# 2                  Treatment of Bacterial infections
# 3                      Treatment of Cough with mucus
# 4  Treatment of Gastroesophageal reflux disease (...
#
#                                         Side_effects  \
# 0  Rectal bleeding Taste change Headache Noseblee...
# ...

# %%
meds.isnull().sum()
# Out:
# Medicine Name         0
# Composition           0
# Uses                  0
# Side_effects          0
# Image URL             0
# Manufacturer          0
# Excellent Review %    0
# Average Review %      0
# Poor Review %         0
# dtype: int64

# %%
# Checking for duplicate entries
meds.duplicated().sum()
# Out:
# 84

# %%
# Dropping duplicate entries
medicines = meds.drop_duplicates()
medicines.duplicated().sum()
# Out:
# 0

# %%
meds.head()
# Out:
#               Medicine Name  \
# 0   Avastin 400mg Injection
# 1  Augmentin 625 Duo Tablet
# 2       Azithral 500 Tablet
# 3          Ascoril LS Syrup
# 4         Aciloc 150 Tablet
#
#                                          Composition  \
# 0                                Bevacizumab (400mg)
# 1    Amoxycillin  (500mg) +  Clavulanic Acid (125mg)
# 2                               Azithromycin (500mg)
# 3  Ambroxol (30mg/5ml) + Levosalbutamol (1mg/5ml)...
# 4                                 Ranitidine (150mg)
#
#                                                 Uses  \
# 0   Cancer of colon and rectum Non-small cell lun...
# 1                  Treatment of Bacterial infections
# 2                  Treatment of Bacterial infections
# 3                      Treatment of Cough with mucus
# 4  Treatment of Gastroesophageal reflux disease (...
#
#                                         Side_effects  \
# 0  Rectal bleeding Taste change Headache Noseblee...
# ...

# %%
meds['Composition'].value_counts()
# Out:
# Luliconazole (1% w/w)                                                                                   98
# Levocetirizine (5mg) + Montelukast (10mg)                                                               77
# Ketoconazole (2% w/w)                                                                                   66
# Domperidone (30mg) + Rabeprazole (20mg)                                                                 60
# Itraconazole (100mg)                                                                                    53
#                                                                                                         ..
# Sodium Picosulfate (3.33mg/5ml) + Liquid Paraffin (1.25ml/5ml) + Milk Of Magnesia (3.75ml/5ml)           1
# Ambroxol (60mg) + Phenylephrine (5mg) + Levocetirizine (5mg)                                             1
# Digoxin (0.25mg)                                                                                         1
# ...

# %%
salts_name = list(meds['Composition'].value_counts().keys())[0:20]
count_of_meds_with_that_salt = list(meds['Composition'].value_counts())[0:20]

# %%
    # Composition

from matplotlib import pyplot as plt

plt.figure(figsize=(20,10))
plt.bar(salts_name, count_of_meds_with_that_salt, color = 'b')
plt.grid(True)
plt.title('Count of Meds with same composition')
plt.xticks(rotation=90)
plt.xlabel('Salts Name')
plt.ylabel('Count Of Medicine')
plt.show()

# %%
meds['Manufacturer'].value_counts()
# Out:
# Sun Pharmaceutical Industries Ltd    820
# Intas Pharmaceuticals Ltd            654
# Cipla Ltd                            574
# Torrent Pharmaceuticals Ltd          445
# Lupin Ltd                            435
#                                     ...
# Universal NutriScience                 1
# Orison Pharma International            1
# Pacific Biotech                        1
# Misae Lifesciences Pvt Ltd             1
# Albia Biocare                          1
# Name: Manufacturer, Length: 759, dtype: int64

# %%
manu_name = list(meds['Manufacturer'].value_counts().keys())[0:30]
count_manufacture_name = list(meds['Manufacturer'].value_counts())[0:30]

# %%
# Manufacturer 

plt.figure(figsize=(20,10))
plt.bar(manu_name, count_manufacture_name, color = 'r')
plt.grid(True)
plt.title('Count of Meds with same Manufacturer')
plt.xticks(rotation=90)
plt.xlabel('Salts Name')
plt.ylabel('Count Of Medicine')
plt.show()

# %%
# Removing + sign between the composition and separating each salt

def convert(input_string):
    # Split the input string using ' + ' as the delimiter
    salts = [item.strip() for item in input_string.split(' + ')]
    return salts

meds['Composition'] = meds['Composition'].apply(convert)

# %%
meds.head()
# Out:
#               Medicine Name  \
# 0   Avastin 400mg Injection
# 1  Augmentin 625 Duo Tablet
# 2       Azithral 500 Tablet
# 3          Ascoril LS Syrup
# 4         Aciloc 150 Tablet
#
#                                          Composition  \
# 0                              [Bevacizumab (400mg)]
# 1    [Amoxycillin  (500mg), Clavulanic Acid (125mg)]
# 2                             [Azithromycin (500mg)]
# 3  [Ambroxol (30mg/5ml), Levosalbutamol (1mg/5ml)...
# 4                               [Ranitidine (150mg)]
#
#                                                 Uses  \
# 0   Cancer of colon and rectum Non-small cell lun...
# 1                  Treatment of Bacterial infections
# 2                  Treatment of Bacterial infections
# 3                      Treatment of Cough with mucus
# 4  Treatment of Gastroesophageal reflux disease (...
#
#                                         Side_effects  \
# 0  Rectal bleeding Taste change Headache Noseblee...
# ...

# %%
# Converting Uses into list
meds['Uses'] = meds['Uses'].apply(lambda x:x.split())

# %%
meds.head()
# Out:
#               Medicine Name  \
# 0   Avastin 400mg Injection
# 1  Augmentin 625 Duo Tablet
# 2       Azithral 500 Tablet
# 3          Ascoril LS Syrup
# 4         Aciloc 150 Tablet
#
#                                          Composition  \
# 0                              [Bevacizumab (400mg)]
# 1    [Amoxycillin  (500mg), Clavulanic Acid (125mg)]
# 2                             [Azithromycin (500mg)]
# 3  [Ambroxol (30mg/5ml), Levosalbutamol (1mg/5ml)...
# 4                               [Ranitidine (150mg)]
#
#                                                 Uses  \
# 0  [Cancer, of, colon, and, rectum, Non-small, ce...
# 1             [Treatment, of, Bacterial, infections]
# 2             [Treatment, of, Bacterial, infections]
# 3                [Treatment, of, Cough, with, mucus]
# 4  [Treatment, of, Gastroesophageal, reflux, dise...
#
#                                         Side_effects  \
# 0  Rectal bleeding Taste change Headache Noseblee...
# ...

# %%
meds['Side_effects'] = meds['Side_effects'].apply(lambda x: x.split())

# %%
meds.head()
# Out:
#               Medicine Name  \
# 0   Avastin 400mg Injection
# 1  Augmentin 625 Duo Tablet
# 2       Azithral 500 Tablet
# 3          Ascoril LS Syrup
# 4         Aciloc 150 Tablet
#
#                                          Composition  \
# 0                              [Bevacizumab (400mg)]
# 1    [Amoxycillin  (500mg), Clavulanic Acid (125mg)]
# 2                             [Azithromycin (500mg)]
# 3  [Ambroxol (30mg/5ml), Levosalbutamol (1mg/5ml)...
# 4                               [Ranitidine (150mg)]
#
#                                                 Uses  \
# 0  [Cancer, of, colon, and, rectum, Non-small, ce...
# 1             [Treatment, of, Bacterial, infections]
# 2             [Treatment, of, Bacterial, infections]
# 3                [Treatment, of, Cough, with, mucus]
# 4  [Treatment, of, Gastroesophageal, reflux, dise...
#
#                                         Side_effects  \
# 0  [Rectal, bleeding, Taste, change, Headache, No...
# ...

# %%
meds['Composition'] = meds['Composition'].apply(lambda x:[i.replace(" ","") for i in x])
meds.head()
# Out:
#               Medicine Name  \
# 0   Avastin 400mg Injection
# 1  Augmentin 625 Duo Tablet
# 2       Azithral 500 Tablet
# 3          Ascoril LS Syrup
# 4         Aciloc 150 Tablet
#
#                                          Composition  \
# 0                               [Bevacizumab(400mg)]
# 1        [Amoxycillin(500mg), ClavulanicAcid(125mg)]
# 2                              [Azithromycin(500mg)]
# 3  [Ambroxol(30mg/5ml), Levosalbutamol(1mg/5ml), ...
# 4                                [Ranitidine(150mg)]
#
#                                                 Uses  \
# 0  [Cancer, of, colon, and, rectum, Non-small, ce...
# 1             [Treatment, of, Bacterial, infections]
# 2             [Treatment, of, Bacterial, infections]
# 3                [Treatment, of, Cough, with, mucus]
# 4  [Treatment, of, Gastroesophageal, reflux, dise...
#
#                                         Side_effects  \
# 0  [Rectal, bleeding, Taste, change, Headache, No...
# ...

# %%
meds['Medicine Score'] = round((meds['Excellent Review %']/100 * 5.0) + (meds['Average Review %']/100 * 3.0) + (meds['Poor Review %']/100 *1.0), 2)

# %%
meds.head()
# Out:
#               Medicine Name  \
# 0   Avastin 400mg Injection
# 1  Augmentin 625 Duo Tablet
# 2       Azithral 500 Tablet
# 3          Ascoril LS Syrup
# 4         Aciloc 150 Tablet
#
#                                          Composition  \
# 0                               [Bevacizumab(400mg)]
# 1        [Amoxycillin(500mg), ClavulanicAcid(125mg)]
# 2                              [Azithromycin(500mg)]
# 3  [Ambroxol(30mg/5ml), Levosalbutamol(1mg/5ml), ...
# 4                                [Ranitidine(150mg)]
#
#                                                 Uses  \
# 0  [Cancer, of, colon, and, rectum, Non-small, ce...
# 1             [Treatment, of, Bacterial, infections]
# 2             [Treatment, of, Bacterial, infections]
# 3                [Treatment, of, Cough, with, mucus]
# 4  [Treatment, of, Gastroesophageal, reflux, dise...
#
#                                         Side_effects  \
# 0  [Rectal, bleeding, Taste, change, Headache, No...
# ...

# %%
meds['Medicine Score'].value_counts()
# Out:
# 4.34    910
# 3.00    697
# 5.00    610
# 3.66    489
# 1.66    421
#        ...
# 4.62      1
# 1.26      1
# 1.62      1
# 1.98      1
# 1.38      1
# Name: Medicine Score, Length: 166, dtype: int64

# %%
medicine_scores = list(meds['Medicine Score'].value_counts().keys())
count_medicine_score = list(meds['Medicine Score'].value_counts())

# %%
index = []
new_scores = []
for i in medicine_scores:
    if i>3.1:
        index.append(medicine_scores.index(i))
        new_scores.append(i)
    else :
        pass

# %%
scores_count = []
for i in index:
    scores_count.append(count_medicine_score[i])

# %%
plt.figure(figsize=(10,8))
plt.bar(new_scores, scores_count, color = 'g')
plt.grid(True)
plt.title('Medicine Score Details')
plt.xticks(rotation=90)
plt.xlabel('Medicine Scores')
plt.ylabel('Count Of Scores')
plt.show()

# %%
meds['tags'] = meds['Composition'] + meds['Uses']

# %%
#revisit
meds['tags_with_side_effects'] = meds['Side_effects'].astype(str)

# %%
meds.head()
# Out:
#               Medicine Name  \
# 0   Avastin 400mg Injection
# 1  Augmentin 625 Duo Tablet
# 2       Azithral 500 Tablet
# 3          Ascoril LS Syrup
# 4         Aciloc 150 Tablet
#
#                                          Composition  \
# 0                               [Bevacizumab(400mg)]
# 1        [Amoxycillin(500mg), ClavulanicAcid(125mg)]
# 2                              [Azithromycin(500mg)]
# 3  [Ambroxol(30mg/5ml), Levosalbutamol(1mg/5ml), ...
# 4                                [Ranitidine(150mg)]
#
#                                                 Uses  \
# 0  [Cancer, of, colon, and, rectum, Non-small, ce...
# 1             [Treatment, of, Bacterial, infections]
# 2             [Treatment, of, Bacterial, infections]
# 3                [Treatment, of, Cough, with, mucus]
# 4  [Treatment, of, Gastroesophageal, reflux, dise...
#
#                                         Side_effects  \
# 0  [Rectal, bleeding, Taste, change, Headache, No...
# ...

# %%
new_df = meds[['Medicine Name', 'Uses', 'Composition', 'Side_effects','tags', 'tags_with_side_effects', 'Manufacturer', 'Medicine Score', 'Image URL']]

# %%
new_df.head()
# Out:
#               Medicine Name  \
# 0   Avastin 400mg Injection
# 1  Augmentin 625 Duo Tablet
# 2       Azithral 500 Tablet
# 3          Ascoril LS Syrup
# 4         Aciloc 150 Tablet
#
#                                                 Uses  \
# 0  [Cancer, of, colon, and, rectum, Non-small, ce...
# 1             [Treatment, of, Bacterial, infections]
# 2             [Treatment, of, Bacterial, infections]
# 3                [Treatment, of, Cough, with, mucus]
# 4  [Treatment, of, Gastroesophageal, reflux, dise...
#
#                                          Composition  \
# 0                               [Bevacizumab(400mg)]
# 1        [Amoxycillin(500mg), ClavulanicAcid(125mg)]
# 2                              [Azithromycin(500mg)]
# 3  [Ambroxol(30mg/5ml), Levosalbutamol(1mg/5ml), ...
# 4                                [Ranitidine(150mg)]
#
#                                         Side_effects  \
# 0  [Rectal, bleeding, Taste, change, Headache, No...
# ...

# %%
new_df['tags'] = new_df['tags'].apply(lambda x:' '.join(x))
# Out:
# C:\Users\TANMAY MAREPALLY\AppData\Local\Temp\ipykernel_23988\1840108476.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['tags'] = new_df['tags'].apply(lambda x:' '.join(x))

# %%
new_df['tags_with_side_effects'] = new_df['tags_with_side_effects'].apply(lambda x: ''.join(x))
# Out:
# C:\Users\TANMAY MAREPALLY\AppData\Local\Temp\ipykernel_23988\1317922642.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['tags_with_side_effects'] = new_df['tags_with_side_effects'].apply(lambda x: ''.join(x))

# %%
new_df['tags']
# Out:
# 0        Bevacizumab(400mg) Cancer of colon and rectum ...
# 1        Amoxycillin(500mg) ClavulanicAcid(125mg) Treat...
# 2        Azithromycin(500mg) Treatment of Bacterial inf...
# 3        Ambroxol(30mg/5ml) Levosalbutamol(1mg/5ml) Gua...
# 4        Ranitidine(150mg) Treatment of Gastroesophagea...
#                                ...
# 11820    Azilsartanmedoxomil(40mg) Chlorthalidone(6.25m...
# 11821    ChromiumPicolinate(100mcg) D-ChiroInositol(13....
# 11822    Sildenafil(100mg) Treatment of Erectile dysfun...
# 11823    Ketoconazole(2%w/v) Zincpyrithione(1%w/v) Trea...
# 11824    Ketoconazole(2%w/v) Zincpyrithione(1%w/v) Trea...
# Name: tags, Length: 11825, dtype: object

# %%
new_df['tags_with_side_effects']
# Out:
# 0        ['Rectal', 'bleeding', 'Taste', 'change', 'Hea...
# 1        ['Vomiting', 'Nausea', 'Diarrhea', 'Mucocutane...
# 2              ['Nausea', 'Abdominal', 'pain', 'Diarrhea']
# 3        ['Nausea', 'Vomiting', 'Diarrhea', 'Upset', 's...
# 4        ['Headache', 'Diarrhea', 'Gastrointestinal', '...
#                                ...
# 11820    ['Dizziness', 'Tiredness', 'Decreased', 'potas...
# 11821    ['Rash', 'Nausea', 'Paresthesia', 'tingling', ...
# 11822    ['Flushing', 'sense', 'of', 'warmth', 'in', 't...
# 11823    ['Application', 'site', 'reactions', 'burning'...
# 11824    ['Application', 'site', 'reactions', 'burning'...
# Name: tags_with_side_effects, Length: 11825, dtype: object

# %%
new_df.head()
# Out:
#               Medicine Name  \
# 0   Avastin 400mg Injection
# 1  Augmentin 625 Duo Tablet
# 2       Azithral 500 Tablet
# 3          Ascoril LS Syrup
# 4         Aciloc 150 Tablet
#
#                                                 Uses  \
# 0  [Cancer, of, colon, and, rectum, Non-small, ce...
# 1             [Treatment, of, Bacterial, infections]
# 2             [Treatment, of, Bacterial, infections]
# 3                [Treatment, of, Cough, with, mucus]
# 4  [Treatment, of, Gastroesophageal, reflux, dise...
#
#                                          Composition  \
# 0                               [Bevacizumab(400mg)]
# 1        [Amoxycillin(500mg), ClavulanicAcid(125mg)]
# 2                              [Azithromycin(500mg)]
# 3  [Ambroxol(30mg/5ml), Levosalbutamol(1mg/5ml), ...
# 4                                [Ranitidine(150mg)]
#
#                                         Side_effects  \
# 0  [Rectal, bleeding, Taste, change, Headache, No...
# ...

# %%
new_df['tags'][1]
# Out:
# 'Amoxycillin(500mg) ClavulanicAcid(125mg) Treatment of Bacterial infections'

# %%
new_df['tags_with_side_effects'][1]
# Out:
# "['Vomiting', 'Nausea', 'Diarrhea', 'Mucocutaneous', 'candidiasis']"

# %%
new_df.head()
# Out:
#               Medicine Name  \
# 0   Avastin 400mg Injection
# 1  Augmentin 625 Duo Tablet
# 2       Azithral 500 Tablet
# 3          Ascoril LS Syrup
# 4         Aciloc 150 Tablet
#
#                                                 Uses  \
# 0  [Cancer, of, colon, and, rectum, Non-small, ce...
# 1             [Treatment, of, Bacterial, infections]
# 2             [Treatment, of, Bacterial, infections]
# 3                [Treatment, of, Cough, with, mucus]
# 4  [Treatment, of, Gastroesophageal, reflux, dise...
#
#                                          Composition  \
# 0                               [Bevacizumab(400mg)]
# 1        [Amoxycillin(500mg), ClavulanicAcid(125mg)]
# 2                              [Azithromycin(500mg)]
# 3  [Ambroxol(30mg/5ml), Levosalbutamol(1mg/5ml), ...
# 4                                [Ranitidine(150mg)]
#
#                                         Side_effects  \
# 0  [Rectal, bleeding, Taste, change, Headache, No...
# ...

# %%
new_df['tags'] = new_df['tags'].apply(lambda x:x.lower())
new_df['tags_with_side_effects'] = new_df['tags_with_side_effects'].apply(lambda x:x.lower())
# Out:
# C:\Users\TANMAY MAREPALLY\AppData\Local\Temp\ipykernel_23988\2790383647.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['tags'] = new_df['tags'].apply(lambda x:x.lower())
# C:\Users\TANMAY MAREPALLY\AppData\Local\Temp\ipykernel_23988\2790383647.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['tags_with_side_effects'] = new_df['tags_with_side_effects'].apply(lambda x:x.lower())

# %%
new_df.head()
# Out:
#               Medicine Name  \
# 0   Avastin 400mg Injection
# 1  Augmentin 625 Duo Tablet
# 2       Azithral 500 Tablet
# 3          Ascoril LS Syrup
# 4         Aciloc 150 Tablet
#
#                                                 Uses  \
# 0  [Cancer, of, colon, and, rectum, Non-small, ce...
# 1             [Treatment, of, Bacterial, infections]
# 2             [Treatment, of, Bacterial, infections]
# 3                [Treatment, of, Cough, with, mucus]
# 4  [Treatment, of, Gastroesophageal, reflux, dise...
#
#                                          Composition  \
# 0                               [Bevacizumab(400mg)]
# 1        [Amoxycillin(500mg), ClavulanicAcid(125mg)]
# 2                              [Azithromycin(500mg)]
# 3  [Ambroxol(30mg/5ml), Levosalbutamol(1mg/5ml), ...
# 4                                [Ranitidine(150mg)]
#
#                                         Side_effects  \
# 0  [Rectal, bleeding, Taste, change, Headache, No...
# ...

# %%
new_df.rename(columns = {'Medicine Name':'Name', }, inplace = True)
new_df.rename(columns = {'Medicine Score':'Score'}, inplace = True)
new_df.rename(columns = {'Image URL':'img_url', }, inplace = True)
# Out:
# C:\Users\TANMAY MAREPALLY\AppData\Local\Temp\ipykernel_23988\2788549837.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df.rename(columns = {'Medicine Name':'Name', }, inplace = True)
# C:\Users\TANMAY MAREPALLY\AppData\Local\Temp\ipykernel_23988\2788549837.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df.rename(columns = {'Medicine Score':'Score'}, inplace = True)
# C:\Users\TANMAY MAREPALLY\AppData\Local\Temp\ipykernel_23988\2788549837.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
new_df.head()
# Out:
#                        Name  \
# 0   Avastin 400mg Injection
# 1  Augmentin 625 Duo Tablet
# 2       Azithral 500 Tablet
# 3          Ascoril LS Syrup
# 4         Aciloc 150 Tablet
#
#                                                 Uses  \
# 0  [Cancer, of, colon, and, rectum, Non-small, ce...
# 1             [Treatment, of, Bacterial, infections]
# 2             [Treatment, of, Bacterial, infections]
# 3                [Treatment, of, Cough, with, mucus]
# 4  [Treatment, of, Gastroesophageal, reflux, dise...
#
#                                          Composition  \
# 0                               [Bevacizumab(400mg)]
# 1        [Amoxycillin(500mg), ClavulanicAcid(125mg)]
# 2                              [Azithromycin(500mg)]
# 3  [Ambroxol(30mg/5ml), Levosalbutamol(1mg/5ml), ...
# 4                                [Ranitidine(150mg)]
#
#                                         Side_effects  \
# 0  [Rectal, bleeding, Taste, change, Headache, No...
# ...

# %%
import nltk
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()

# %%
def stem(text):
    y = []
    for i in text.split():
        y.append(ps.stem(i))
        
    return " ".join(y)

# %%
new_df['tags'] = new_df['tags'].apply(stem)
# Out:
# C:\Users\TANMAY MAREPALLY\AppData\Local\Temp\ipykernel_23988\3213734980.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['tags'] = new_df['tags'].apply(stem)

# %%
#revisit
new_df['tags_with_side_effects'] = new_df['tags_with_side_effects'].apply(stem)
# Out:
# C:\Users\TANMAY MAREPALLY\AppData\Local\Temp\ipykernel_23988\331423253.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['tags_with_side_effects'] = new_df['tags_with_side_effects'].apply(stem)

# %%
new_df.head()
# Out:
#                        Name  \
# 0   Avastin 400mg Injection
# 1  Augmentin 625 Duo Tablet
# 2       Azithral 500 Tablet
# 3          Ascoril LS Syrup
# 4         Aciloc 150 Tablet
#
#                                                 Uses  \
# 0  [Cancer, of, colon, and, rectum, Non-small, ce...
# 1             [Treatment, of, Bacterial, infections]
# 2             [Treatment, of, Bacterial, infections]
# 3                [Treatment, of, Cough, with, mucus]
# 4  [Treatment, of, Gastroesophageal, reflux, dise...
#
#                                          Composition  \
# 0                               [Bevacizumab(400mg)]
# 1        [Amoxycillin(500mg), ClavulanicAcid(125mg)]
# 2                              [Azithromycin(500mg)]
# 3  [Ambroxol(30mg/5ml), Levosalbutamol(1mg/5ml), ...
# 4                                [Ranitidine(150mg)]
#
#                                         Side_effects  \
# 0  [Rectal, bleeding, Taste, change, Headache, No...
# ...

# %%
#Feature Vectorization
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features = 5000, stop_words='english')

# %%
vector  = cv.fit_transform(new_df['tags']).toarray()

# %%
len(vector[0])
# Out:
# 2137

# %%
len(cv.get_feature_names_out())
# Out:
# 2137

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity = cosine_similarity(vector)
similarity.shape
# Out:
# (11825, 11825)

# %%
sorted(list(enumerate(similarity[0])), reverse = True, key = lambda x:x[1])[1:6]
# Out:
# [(3289, 0.8111071056538128),
#  (6735, 0.6936879756192961),
#  (1739, 0.6847623832623259),
#  (1740, 0.6847623832623259),
#  (11749, 0.6847623832623259)]

# %%
# Recommendations based on medicine name
def recommend(medicine):
    recommended_medicine = []
    med_index = new_df[new_df['Name'] == medicine].index[0]
    distances = similarity[med_index]
    med_list = sorted(list(enumerate(distances)), reverse = True, key = lambda x:x[1])[1:51]
    for i in med_list:
        recommended_medicine.append([new_df.iloc[i[0]].Name, new_df.iloc[i[0]].Score])

    recommendations = sorted(recommended_medicine,reverse = True, key = lambda x:x[1])
    seen = set()
    recommended_medicines = [x for x in recommendations if tuple(x) not in seen and not seen.add(tuple(x))]
    
    for i in recommended_medicines:
        print(i)

# %%
recommend('Azithral 500 Tablet')
# Out:
# ['Azithral 500mg Injection', 5.0]
# ['Azithral Eye Drop', 4.66]
# ['Azee 1000 Tablet', 4.66]
# ['Aziquest 500mg Tablet', 4.34]
# ['Azee 100mg Tablet DT', 4.34]
# ['Azithral KidTab', 4.34]
# ['Zatura 500 Tablet', 4.16]
# ['Azee 250 Tablet', 3.98]
# ['Aziwok 600 Tablet', 3.88]
# ['Azimax 250 Tablet', 3.68]
# ['Azimax 500 Tablet', 3.66]
# ['Azee 250 Tablet', 3.64]
# ['Azee 500 Tablet', 3.52]
# ['Altacef 500 Tablet', 3.4]
# ['Ibithral 500mg Tablet', 3.38]
# ['Zithrolect 500 Tablet', 3.34]
# ['Alevo 500 Tablet', 3.34]
# ['Hhazi 500 Tablet', 3.32]
# ['Uthral 500mg Tablet', 3.32]
# ['ATM 500 Tablet', 3.28]
# ['Azikem 500mg Tablet', 3.26]
# ['Azee 500 Tablet', 3.24]
# ['Trulimax 500mg Tablet', 3.22]
# ['Zathrin 500 Tablet', 3.22]
# ['Azax 500 Tablet', 3.16]
# ['Almox 500 Capsule', 3.12]
# ['Aziwok 500 Tablet', 3.04]
# ['Azicip 500 Tablet', 3.02]
# ['Althrocin 500 Tablet', 3.0]
# ['Azax 250 Tablet', 3.0]
# ['Azifast 250 Tablet', 3.0]
# ['Azifast 500 Tablet', 2.98]
# ...

# %%
# Recommendations based on medicine composition

def recommend_medicine(composition_queries):
    recommendations = []

    # Check for medicines that contain all specified compositions
    for index, row in new_df.iterrows():
        composition = row['Composition']
        if isinstance(composition, list):
            # Check if all composition items are present in the medicine
            if all(query.lower() in ' '.join(composition).lower() for query in composition_queries):
                recommendations.append([row['Name'],  row['Score']])

   

    if recommendations:
        # Remove duplicates and return the recommendations
        medicine_list = sorted(recommendations, reverse = True, key = lambda x:x[1])[:50]
        seen = set()
        recommended_medicines = [x for x in medicine_list if tuple(x) not in seen and not seen.add(tuple(x))]
        return recommended_medicines
    else:
        return "No matching medicines found."

# %%
recommend_medicine(["Amoxycillin(500mg)", "ClavulanicAcid(125mg)"])
# Out:
# [['Evoxil CV 500mg/125mg Tablet', 5.0],
#  ['Lmx Forte 500mg/125mg Tablet', 5.0],
#  ['Goldclav 625 Tablet', 4.34],
#  ['Lacom-CV 625 Tablet', 4.34],
#  ['Oro-CV 625 Tablet', 4.12],
#  ['Erox CV 625 Tablet', 4.0],
#  ['Tresmox CV 500mg/125mg Tablet', 3.88],
#  ['Zovax CV 625 Tablet', 3.66],
#  ['Bactoclav 625 Tablet', 3.62],
#  ['Novamox CV 625mg Tablet', 3.6],
#  ['Xoclave 625 Tablet', 3.6],
#  ['Augmentin 625 Duo Tablet', 3.58],
#  ['Advent 625 Tablet', 3.56],
#  ['Acuclav 625 Tablet', 3.52],
#  ['Polyclav 625mg Tablet', 3.52],
#  ['Pexoclav 625 Tablet', 3.46],
#  ['Rapiclav 625 Tablet', 3.44],
#  ['Novaclav 625 Tablet', 3.38],
#  ['Moxikind-CV 625 Tablet', 3.34],
#  ['Amoxyclav 625 Tablet', 3.3],
#  ['Sensiclav 625 Tablet', 3.28],
#  ['Augpen 625 BID Tablet', 3.16],
#  ['Hhamclav 625 Tablet', 3.16],
#  ['Penclav 625 Tablet', 3.14],
#  ['Mega-CV 625 Tablet', 3.06],
#  ['Mox CV 625 Tablet', 3.06],
#  ['Mpx-CV 625 Tablet', 3.0],
#  ['Miliclav Tablet', 3.0],
# ...

# %%
def recommend_medicine1(use_query):
    recommendations = []

    
    for index, row in new_df.iterrows():
        use = row['Uses']
        if isinstance(use, list):
            # Check if all composition items are present in the medicine
            if all(query.lower() in ' '.join(use).lower() for query in use_query):
                recommendations.append([row['Name'],  row['Score']])

   

    if recommendations:
        
        medicine_list = sorted(recommendations, reverse = True, key = lambda x:x[1])[:50]
        seen = set()
        recommended_medicines = [x for x in medicine_list if tuple(x) not in seen and not seen.add(tuple(x))]
        return recommended_medicines
    else:
        return "No medicines found for this disease."

# %%
recommend_medicine1(['high cholesterol'])
# Out:
# [['Atormac CV10 Capsule', 5.0],
#  ['Atorva 5 Tablet', 5.0],
#  ['ATR-F Tablet', 5.0],
#  ['Atorsave 40 Tablet', 5.0],
#  ['Azuvas 10 Tablet', 5.0],
#  ['Atocor 5 Tablet', 5.0],
#  ['Atormac 40 Tablet', 5.0],
#  ['Atorec CV 10 Capsule', 5.0],
#  ['Atorlip 80 Tablet', 5.0],
#  ['Atorin 20 Tablet', 5.0],
#  ['Daztor 20 Tablet', 5.0],
#  ['Dysliptin 20 Tablet', 5.0],
#  ['Finobrate 145mg Tablet', 5.0],
#  ['Glyvas F Tablet', 5.0],
#  ['Inovas F Tablet', 5.0],
#  ['Lipitas 5mg Tablet', 5.0],
#  ['Lipigo 5 Tablet', 5.0],
#  ['Mactor 10 Tablet', 5.0],
#  ['Novastat EZ 10mg/10mg Tablet', 5.0],
#  ['Rosuvas CV 20mg/75mg Tablet', 5.0],
#  ['Rosufit-F 10/160 Tablet', 5.0],
#  ['Rosulip-F 5 Tablet', 5.0],
#  ['Rozustat F 5 Tablet', 5.0],
#  ['Rostar 20 Tablet', 5.0],
#  ['Roslaren 40 Tablet', 5.0],
#  ['Rosta 10 Tablet', 5.0],
#  ['Rastrol 20 Tablet', 5.0],
#  ['Statpure 20 Tablet', 5.0],
#  ['Stator 80 Tablet', 5.0],
#  ['Simvotin 5 Tablet', 5.0],
#  ['Turbovas-F Tablet', 5.0],
# ...

# %%
def display_symptoms(medical_history):
    symptoms = {
        "Anxiety": ["Feeling nervous, restless or tense",
                    "Having a sense of impending danger, panic or doom",
                    "Having an increased heart rate",
                    "Breathing rapidly (hyperventilation)",
                    "Sweating",
                    "Having trouble sleeping"],
        "Arthritis": ["Pain",
                      "Stiffness",
                      "Swelling",
                      "Redness",
                      "Decreased range of motion"],
        "Asthma": ["Shortness of breath",
                   "Chest tightness or pain",
                   "Wheezing when exhaling",
                   "Trouble sleeping",
                   "Coughing"],
        "Blood clots": ["Arms and legs: Pain or tenderness, swelling, or warm feeling",
                        "Brain: Trouble speaking; vision changes; sudden, strong headache; dizziness; or weakness in face, arms, or legs",
                        "Heart: Pain in the chest or other part of the upper body, breathing difficulties, sweating, nausea, or light-headedness",
                        "Lungs: Chest pain, difficulty breathing, rapid heartbeat, sweating, fever, or coughing up blood"],
        "Chronic pain": ["Arthritis, or joint pain.",
                         "Back pain.",
                         "Neck pain.",
                         "Cancer pain near a tumor.",
                         "Headaches, including migraines"],
        "Depression": ["Feelings of sadness, tearfulness, emptiness or hopelessness",
                       "Angry outbursts, irritability or frustration, even over small matters",
                       "Loss of interest or pleasure in most or all normal activities, such as sex, hobbies or sports",
                       "Sleep disturbances, including insomnia or sleeping too much."],
        "Diabetes": ["Feeling more thirsty than usual.",
                     "Urinating often.",
                     "Losing weight without trying.",
                     "Feeling irritable or having other mood changes.",
                     "Having blurry vision.",
                     "Having slow-healing sores."],
        "High Blood Pressure": ["severe headaches.",
                                 "chest pain.",
                                 "dizziness.",
                                 "difficulty breathing.",
                                 "nausea.",
                                 "vomiting."],
        "HIV": ["Fever.",
                "Fatigue.",
                "Swollen lymph glands, which are often one of the first symptoms of HIV infection.",
                "Diarrhea.",
                "Weight loss.",
                "Oral yeast infection, also called thrush.",
                "Pneumonia."],
        "Seizures": ["Temporary confusion.",
                     "A staring spell.",
                     "Jerking movements of the arms and legs that can't be controlled.",
                     "Loss of consciousness or awareness.",
                     "Cognitive or emotional changes"]
    }

    if medical_history in symptoms:
        print(f"Symptoms for {medical_history}:")
        for symptom in symptoms[medical_history]:
            print(symptom)
        print("\n")  
    else:
        print("No symptoms available for the selected medical history.")


def display_medical_history():
    print("Select from the following medical histories (press Enter after each selection):")
    print("1. Anxiety\n2. Arthritis\n3. Asthma\n4. Blood clots\n5. Chronic pain\n6. Depression\n7. Diabetes\n8. High Blood Pressure\n9. HIV\n10. Seizures")
    medical_histories = []
    while True:
        choice = input("Enter the number corresponding to the medical history (or '0' if finished): ")
        if choice == '0':
            break
        elif choice.isdigit():
            choice = int(choice)
            if choice >= 1 and choice <= 10:
                if choice == 1:
                    medical_histories.append("Anxiety")
                elif choice == 2:
                    medical_histories.append("Arthritis")
                elif choice == 3:
                    medical_histories.append("Asthma")
                elif choice == 4:
                    medical_histories.append("Blood clots")
                elif choice == 5:
                    medical_histories.append("Chronic pain")
                elif choice == 6:
                    medical_histories.append("Depression")
                elif choice == 7:
                    medical_histories.append("Diabetes")
                elif choice == 8:
                    medical_histories.append("High Blood Pressure")
                elif choice == 9:
                    medical_histories.append("HIV")
                elif choice == 10:
                    medical_histories.append("Seizures")
            else:
                print("Invalid choice. Please enter a number between 1 and 10.")
        else:
            print("Invalid input. Please enter a number.")

    if medical_histories:
        for history in medical_histories:
            display_symptoms(history)
    else:
        print("No medical history selected.")



def get_recommendations():  
    print("Based on Condition/Symptom") 
    disease = input("Enter the condition/symptom: ")
    recommendations = recommend_medicine1([disease])
    if recommendations != "No medicines found for this disease.":
        print("Top 5 recommended medicines for", disease, "are:")
        for med in recommendations[:5]:
            medicine = new_df[new_df['Name'] == med[0]].iloc[0]
            print("Medicine:", medicine['Name'])
            print("Composition:", ', '.join(medicine['Composition']))
            print("Side Effects:", medicine['tags_with_side_effects'])
            print("Manufacturer:", medicine['Manufacturer'])
            print("Image URL:", medicine['img_url'])
            print()
    else:
         print("No medicines found for", disease)
    
def get_recommendations():
    print("Based on Condition/Symptom")   
    disease = input("Enter the condition/symptom: ")
    recommendations = recommend_medicine1([disease])
    if recommendations != "No medicines found for this disease.":
        print("Top 5 recommended medicines for", disease, "are:")
        for med in recommendations[:5]:
            medicine = new_df[new_df['Name'] == med[0]].iloc[0]
            print("Medicine:", medicine['Name'])
            print("Composition:", ', '.join(medicine['Composition']))
            print("Side Effects:", medicine['tags_with_side_effects'])
            print("Manufacturer:", medicine['Manufacturer'])
            print("Image URL:", medicine['img_url'])
            print()
    else:
         print("No medicines found for", disease)
    

display_medical_history()
get_recommendations()
# Out:
# Select from the following medical histories (press Enter after each selection):
# 1. Anxiety
# 2. Arthritis
# 3. Asthma
# 4. Blood clots
# 5. Chronic pain
# 6. Depression
# 7. Diabetes
# 8. High Blood Pressure
# 9. HIV
# 10. Seizures
# Enter the number corresponding to the medical history (or '0' if finished): 0
# No medical history selected.
# Based on Condition/Symptom
# Enter the condition/symptom: cold
# Top 5 recommended medicines for cold are:
# Medicine: New Coldact Capsule SR
# Composition: ChlorpheniramineMaleate(8mg), Phenylephrine(20mg)
# Side Effects: ['vomiting', 'headache', 'restlessness', 'anxiety', 'dizziness', 'tremors', 'pale', 'skin', 'high', 'blood', 'pressure', 'seizure', 'cerebral', 'hemorrhage', 'palpitations', 'paresthesia', 'tingling', 'or', 'pricking', 'sensation', 'abdominal', 'pain', 'allergic', 'reaction', 'decreased', 'appetite', 'blurred', 'vision', 'dry', 'nose', 'dry', 'throat', 'excitement', 'rash']
# Manufacturer: Sun Pharmaceutical Industries Ltd
# ...
